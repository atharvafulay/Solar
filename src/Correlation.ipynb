# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="127.0.0.1",
  user="root",
  password="*",
  database="solarschema"
#   auth_plugin='mysql_native_password'
)
mycursor = mydb.cursor()

mycursor.execute("""
select * 
from solar s
join demohousehold dh on s.region_name = dh.`GEO.id2`
join demoracelatino dra on s.region_name = dra.`GEO.id2`
join demorelationships dre on s.region_name = dre.`GEO.id2`
join demosexage ds on s.region_name = ds.`GEO.id2`
join income i on s.region_name = i.ZIPCODE
WHERE s.count_qualified > 25
""")

myresult = mycursor.fetchall()

zips = list()
for x in myresult:
    zips.append(x[0])
    
import pandas as pd
# mydb
query = pd.read_sql_query("""
select * from solar s
join demohousehold dh on s.region_name = dh.`GEO.id2`
join demoracelatino dra on s.region_name = dra.`GEO.id2`
join demorelationships dre on s.region_name = dre.`GEO.id2`
join demosexage ds on s.region_name = ds.`GEO.id2`
join income i on s.region_name = i.ZIPCODE
WHERE s.count_qualified > 25
""", mydb)
df = pd.DataFrame(query)

# %%
query = pd.read_sql_query("""
select * from solar s
join demohousehold dh on s.region_name = dh.`GEO.id2`
join demoracelatino dra on s.region_name = dra.`GEO.id2`
join demorelationships dre on s.region_name = dre.`GEO.id2`
join demosexage ds on s.region_name = ds.`GEO.id2`
WHERE s.count_qualified > 25
""", mydb)



cols = ['region_name',
'state_name',
'lat_max',
'lat_min',
'lng_max',
'lng_min',
'lat_avg',
'lng_avg',
'yearly_sunlight_kwh_kw_threshold_avg',
'count_qualified',
'percent_covered',
'percent_qualified',
'number_of_panels_n',
'number_of_panels_s',
'number_of_panels_e',
'number_of_panels_w',
'number_of_panels_f',
'number_of_panels_median',
'number_of_panels_total',
'kw_median',
'kw_total',
'yearly_sunlight_kwh_n',
'yearly_sunlight_kwh_s',
'yearly_sunlight_kwh_e',
'yearly_sunlight_kwh_w',
'yearly_sunlight_kwh_f',
'yearly_sunlight_kwh_median',
'yearly_sunlight_kwh_total',
'install_size_kw_buckets',
'carbon_offset_metric_tons',
'existing_installs_count',
'center_point',
'HD01_S001',
'HD02_S001',
'HD01_S002',
'HD02_S002',
'HD01_S003',
'HD02_S003',
'HD01_S004',
'HD02_S004',
'HD01_S005',
'HD02_S005',
'HD01_S006',
'HD02_S006',
'HD01_S007',
'HD02_S007',
'HD01_S008',
'HD02_S008',
'HD01_S009',
'HD02_S009',
'HD01_S010',
'HD02_S010',
'HD01_S011',
'HD02_S011',
'HD01_S012',
'HD02_S012',
'HD01_S013',
'HD02_S013',
'HD01_S014',
'HD02_S014',
'HD01_S015',
'HD02_S015',
'HD01_S016',
'HD02_S016',
'HD01_S017',
'HD02_S017',
'HD01_S018',
'HD02_S018',
'HD01_S019',
'HD02_S019',
'HD01_S020',
'HD02_S020',
'HD01_S021',
'HD02_S021',
'HD01_S022',
'HD02_S022',
'HD01_S023',
'HD02_S023',
'HD01_S024',
'HD01_S181',
'HD02_S181',
'HD01_S182',
'HD02_S182',
'HD01_S183',
'HD02_S183',
'HD01_S184',
'HD02_S184',
'HD01_S185',
'HD02_S185',
'HD01_S186',
'HD02_S186',
'curr_production']

df = pd.DataFrame(query)
df['curr_production'] = df['kw_total'] * df['existing_installs_count'] / df['count_qualified']

df1 = df[cols].dropna(0)

# %%
import seaborn as sns
corr = df.corr(method='pearson')
# ax = sns.heatmap(
#     corr, 
#     vmin=-1, vmax=1, center=0,
#     cmap=sns.diverging_palette(20, 220, n=200),
#     square=True
# )
# ax.set_xticklabels(
#     ax.get_xticklabels(),
#     rotation=45,
#     horizontalalignment='right'
# );

# %%
df = pd.DataFrame(query)
df['curr_production'] = df['kw_total'] * df['existing_installs_count'] / df['count_qualified']
corr = df.corr(method='pearson')
corr['curr_production'].sort_values(ascending=False).dropna(0).head(25)

# %%
corr['curr_production'].sort_values(ascending=False).dropna(0)
# Out:
# curr_production            1.000000
# existing_installs_count    0.971797
# HD01_S097                  0.555147
# yearly_sunlight_kwh_e      0.527487
# yearly_sunlight_kwh_w      0.519162
#                              ...
# lat_avg                   -0.245400
# HD02_S077                 -0.334286
# lng_min                   -0.364083
# lng_avg                   -0.364242
# lng_max                   -0.364384
# Name: curr_production, Length: 382, dtype: float64

# %%
corr['curr_production'].sort_values(ascending=True).dropna(0).head(10)
# Out:
# lng_max     -0.364384
# lng_avg     -0.364242
# lng_min     -0.364083
# HD02_S077   -0.334286
# lat_avg     -0.245400
# lat_max     -0.245336
# lat_min     -0.245334
# HD02_S112   -0.124804
# HD02_S122   -0.124804
# HD02_S124   -0.109017
# Name: curr_production, dtype: float64

# %%
corr['HD01_S097'].sort_values(ascending=False).dropna(0).head(11)
# Out:
# HD01_S097                  1.000000
# HD01_S129                  0.839119
# HD01_S095                  0.775412
# HD02_S097                  0.775087
# HD01_S103                  0.736665
# HD01_S118                  0.708820
# HD01_S081                  0.677190
# HD01_S126                  0.673865
# HD01_S085                  0.622241
# HD02_S103                  0.617258
# existing_installs_count    0.592067
# Name: HD01_S097, dtype: float64

# %%
corr['HD01_S118'].sort_values(ascending=False).dropna(0).head(10)
# Out:
# HD01_S118    1.000000
# HD01_S095    0.814798
# HD02_S118    0.808229
# HD01_S084    0.779419
# HD01_S121    0.733239
# HD01_S103    0.730180
# HD01_S119    0.728816
# HD01_S097    0.708820
# HD01_S081    0.687167
# HD01_S129    0.682226
# Name: HD01_S118, dtype: float64

# %%
query = pd.read_sql_query("""
select * from solar s
join income i on s.region_name = i.ZIPCODE
WHERE s.count_qualified > 25
""", mydb)
df2 = pd.DataFrame(query)


df2['curr_production'] = df2['kw_total'] * df2['existing_installs_count'] / df2['count_qualified']

df2 = df2.dropna(0)

# %%
corr = df.corr(method='pearson')
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);
